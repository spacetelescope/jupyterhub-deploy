# %% [markdown]
# # Example of Reducing JWST NIRCam observations

# %% [markdown]
# JWST calibration pipeline software is currently under active development. It is not yet supported for public use, but it is available publically in a GitHub repository: https://github.com/spacetelescope/jwst. Please see the README there for more information about installation.

# %% [markdown]
# # Data
#
# WFIRST WFI images will share many similar properties to the JWST NIRCam instrument.
#
# The table below compares the file names that have been used for HST and JWST to the different levels of data for WFIRST.  It also includes the expected size from the DMS Operations Concept for a single exposure or frame.
#
#
# | Description | HST File Name | JWST File Name  | WFIRST Level
# |-------------|---------------|----------------|-----------------
# | Telemetry from Space Craft | Science telemetry | Science telemetry | Level 0 |
# | Uncalibrated Data | raw | uncal | Level 1 | 604 MB
# | Rate Image        |  ima   | rate or rateints |   NA   |
# | Calibrated Exposure | flc/flt | cal or calints | Level 2 | 3 GB
# | Resample and combined exposure | drz | i2d | Level 3
# | Source Catalog | NA | cat  | Level 4
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/data_products/product_types.html

# %%
import jwst
from jwst import datamodels

# %%
# retrieve the data for notebook
from urllib.request import urlretrieve
urlretrieve('https://data.science.stsci.edu/redirect/WFIRST/Tutorials/jwst_example/jw42424001001_01101_00001_nrcb1_uncal.fits', 
            'jw42424001001_01101_00001_nrcb1_uncal.fits')
# Out:
# ('jw42424001001_01101_00001_nrcb1_uncal.fits',
#  <http.client.HTTPMessage at 0x7f69cba34090>)

# %%
im = datamodels.open('jw42424001001_01101_00001_nrcb1_uncal.fits')

# %%
print(im)
# Out:
# <RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>

# %%
print(im.info())
# Out:
# filename: jw42424001001_01101_00001_nrcb1_uncal.fits
# date: 2020-02-26T02:40:13.519
# model_type: RampModel
# ----------------------------------------------------------------------
# attribute                               size                type
# ----------------------------------------------------------------------
# data                                    (2048,2048,4,1)     float32
# group                                   4R x 13C            (integration_number:I,group_number:I,end_day:I,end_milliseconds:J,end_submilliseconds:I,group_end_time:26A,number_of_columns:I,number_of_rows:I,number_of_gaps:I,completion_code_number:I,completion_code_text:36A,bary_end_time:D,helio_end_time:D)
# zeroframe                               (2048,2048,1)       float32
# pixeldq                                 (2048,2048)         uint32
# groupdq                                 (2048,2048,4,1)     uint8
# err                                     (2048,2048,4,1)     float32

# %%
im.meta.instrument.name
# Out:
# 'NIRCAM'

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from astropy.visualization import (MinMaxInterval, SqrtStretch, ImageNormalize)

image = im.data[0][3]
print(image.shape)
norm = ImageNormalize(image, vmin=1000, vmax=10000,
                      stretch=SqrtStretch())

plt.imshow(image, norm=norm)
# Out:
# (2048, 2048)

# %% [markdown]
# # Stages and Pipelines
#
# The JWST Data Reduction Pipeline (typically referred to as the "calibration pipeline") processes data from all instruments and observing modes, producing both fully calibrated individual exposures and high level data products (mosaics, extracted spectra, etc.). It is organized in stages by type of observations. The algorithms and overall structure of the pipeline are decided by an inclusive working group. The details about how to install and run the calibration pipeline are provided.

# %%
from jwst.pipeline import Detector1Pipeline

# %%
pipe = Detector1Pipeline()
pipe.save_calibrated_ramp = True
# Out:
# 2020-03-04 17:30:48,615 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# INFO:stpipe.Detector1Pipeline:Detector1Pipeline instance created.
# 2020-03-04 17:30:48,618 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# INFO:stpipe.Detector1Pipeline.group_scale:GroupScaleStep instance created.
# 2020-03-04 17:30:48,620 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# INFO:stpipe.Detector1Pipeline.dq_init:DQInitStep instance created.
# 2020-03-04 17:30:48,622 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# INFO:stpipe.Detector1Pipeline.saturation:SaturationStep instance created.
# 2020-03-04 17:30:48,625 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# INFO:stpipe.Detector1Pipeline.ipc:IPCStep instance created.
# 2020-03-04 17:30:48,627 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# INFO:stpipe.Detector1Pipeline.superbias:SuperBiasStep instance created.
# 2020-03-04 17:30:48,630 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# INFO:stpipe.Detector1Pipeline.refpix:RefPixStep instance created.
# 2020-03-04 17:30:48,633 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# INFO:stpipe.Detector1Pipeline.rscd:RSCD_Step instance created.
# 2020-03-04 17:30:48,636 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# INFO:stpipe.Detector1Pipeline.firstframe:FirstFrameStep instance created.
# 2020-03-04 17:30:48,638 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# INFO:stpipe.Detector1Pipeline.lastframe:LastFrameStep instance created.
# 2020-03-04 17:30:48,641 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# INFO:stpipe.Detector1Pipeline.linearity:LinearityStep instance created.
# 2020-03-04 17:30:48,643 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# INFO:stpipe.Detector1Pipeline.dark_current:DarkCurrentStep instance created.
# 2020-03-04 17:30:48,645 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# INFO:stpipe.Detector1Pipeline.persistence:PersistenceStep instance created.
# 2020-03-04 17:30:48,648 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# INFO:stpipe.Detector1Pipeline.jump:JumpStep instance created.
# 2020-03-04 17:30:48,651 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# INFO:stpipe.Detector1Pipeline.ramp_fit:RampFitStep instance created.
# 2020-03-04 17:30:48,654 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# INFO:stpipe.Detector1Pipeline.gain_scale:GainScaleStep instance created.

# %%
result = pipe.call(im)
# Out:
# 2020-03-04 17:30:52,077 - CRDS - ERROR -  Error determining best reference for 'pars-groupscalestep'  =   Unknown reference type 'pars-groupscalestep'
# 2020-03-04 17:30:52,086 - CRDS - ERROR -  Error determining best reference for 'pars-dqinitstep'  =   Unknown reference type 'pars-dqinitstep'
# 2020-03-04 17:30:52,091 - CRDS - ERROR -  Error determining best reference for 'pars-saturationstep'  =   Unknown reference type 'pars-saturationstep'
# 2020-03-04 17:30:52,096 - CRDS - ERROR -  Error determining best reference for 'pars-ipcstep'  =   Unknown reference type 'pars-ipcstep'
# 2020-03-04 17:30:52,101 - CRDS - ERROR -  Error determining best reference for 'pars-superbiasstep'  =   Unknown reference type 'pars-superbiasstep'
# 2020-03-04 17:30:52,107 - CRDS - ERROR -  Error determining best reference for 'pars-refpixstep'  =   Unknown reference type 'pars-refpixstep'
# 2020-03-04 17:30:52,112 - CRDS - ERROR -  Error determining best reference for 'pars-rscd_step'  =   Unknown reference type 'pars-rscd_step'
# 2020-03-04 17:30:52,117 - CRDS - ERROR -  Error determining best reference for 'pars-firstframestep'  =   Unknown reference type 'pars-firstframestep'
# 2020-03-04 17:30:52,122 - CRDS - ERROR -  Error determining best reference for 'pars-lastframestep'  =   Unknown reference type 'pars-lastframestep'
# 2020-03-04 17:30:52,127 - CRDS - ERROR -  Error determining best reference for 'pars-linearitystep'  =   Unknown reference type 'pars-linearitystep'
# 2020-03-04 17:30:52,132 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   Unknown reference type 'pars-darkcurrentstep'
# 2020-03-04 17:30:52,138 - CRDS - ERROR -  Error determining best reference for 'pars-persistencestep'  =   Unknown reference type 'pars-persistencestep'
# 2020-03-04 17:30:52,143 - CRDS - ERROR -  Error determining best reference for 'pars-jumpstep'  =   Unknown reference type 'pars-jumpstep'
# 2020-03-04 17:30:52,149 - CRDS - ERROR -  Error determining best reference for 'pars-rampfitstep'  =   Unknown reference type 'pars-rampfitstep'
# 2020-03-04 17:30:52,154 - CRDS - ERROR -  Error determining best reference for 'pars-gainscalestep'  =   Unknown reference type 'pars-gainscalestep'
# 2020-03-04 17:30:52,168 - CRDS - ERROR -  Error determining best reference for 'pars-detector1pipeline'  =   Unknown reference type 'pars-detector1pipeline'
# 2020-03-04 17:30:52,176 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# INFO:stpipe.Detector1Pipeline:Detector1Pipeline instance created.
# 2020-03-04 17:30:52,178 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# INFO:stpipe.Detector1Pipeline.group_scale:GroupScaleStep instance created.
# 2020-03-04 17:30:52,179 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# INFO:stpipe.Detector1Pipeline.dq_init:DQInitStep instance created.
# 2020-03-04 17:30:52,181 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# INFO:stpipe.Detector1Pipeline.saturation:SaturationStep instance created.
# 2020-03-04 17:30:52,183 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# INFO:stpipe.Detector1Pipeline.ipc:IPCStep instance created.
# 2020-03-04 17:30:52,184 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# INFO:stpipe.Detector1Pipeline.superbias:SuperBiasStep instance created.
# 2020-03-04 17:30:52,186 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# INFO:stpipe.Detector1Pipeline.refpix:RefPixStep instance created.
# 2020-03-04 17:30:52,188 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# INFO:stpipe.Detector1Pipeline.rscd:RSCD_Step instance created.
# 2020-03-04 17:30:52,189 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# INFO:stpipe.Detector1Pipeline.firstframe:FirstFrameStep instance created.
# 2020-03-04 17:30:52,192 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# INFO:stpipe.Detector1Pipeline.lastframe:LastFrameStep instance created.
# 2020-03-04 17:30:52,193 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# INFO:stpipe.Detector1Pipeline.linearity:LinearityStep instance created.
# 2020-03-04 17:30:52,195 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# INFO:stpipe.Detector1Pipeline.dark_current:DarkCurrentStep instance created.
# 2020-03-04 17:30:52,197 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# INFO:stpipe.Detector1Pipeline.persistence:PersistenceStep instance created.
# 2020-03-04 17:30:52,199 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# INFO:stpipe.Detector1Pipeline.jump:JumpStep instance created.
# 2020-03-04 17:30:52,201 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# INFO:stpipe.Detector1Pipeline.ramp_fit:RampFitStep instance created.
# 2020-03-04 17:30:52,203 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# INFO:stpipe.Detector1Pipeline.gain_scale:GainScaleStep instance created.
# 2020-03-04 17:30:52,299 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline:Step Detector1Pipeline running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:52,310 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}, 'jump': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_result ...
# INFO:stpipe.Detector1Pipeline:Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}, 'jump': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suf ...
# 2020-03-04 17:30:52,322 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw42424001001_01101_00001_nrcb1_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# INFO:stpipe.Detector1Pipeline:Prefetching reference files for dataset: 'jw42424001001_01101_00001_nrcb1_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2020-03-04 17:30:52,345 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_dark_0044.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for DARK reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_dark_0044.fits'.
# 2020-03-04 17:30:52,350 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_gain_0053.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for GAIN reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_gain_0053.fits'.
# 2020-03-04 17:30:52,354 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0029.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for IPC reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0029.fits'.
# 2020-03-04 17:30:52,358 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0057.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for LINEARITY reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0057.fits'.
# 2020-03-04 17:30:52,362 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_mask_0036.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for MASK reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_mask_0036.fits'.
# 2020-03-04 17:30:52,366 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_persat_0011.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for PERSAT reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_persat_0011.fits'.
# 2020-03-04 17:30:52,371 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0039.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for READNOISE reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0039.fits'.
# 2020-03-04 17:30:52,375 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# INFO:stpipe.Detector1Pipeline:Prefetch for REFPIX reference file is 'N/A'.
# 2020-03-04 17:30:52,376 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is 'N/A'.
# INFO:stpipe.Detector1Pipeline:Prefetch for RSCD reference file is 'N/A'.
# 2020-03-04 17:30:52,377 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0058.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for SATURATION reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0058.fits'.
# 2020-03-04 17:30:52,381 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0020.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for SUPERBIAS reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0020.fits'.
# 2020-03-04 17:30:52,385 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_trapdensity_0001.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for TRAPDENSITY reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_trapdensity_0001.fits'.
# 2020-03-04 17:30:52,389 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_trappars_0001.fits'.
# INFO:stpipe.Detector1Pipeline:Prefetch for TRAPPARS reference file is '/home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_trappars_0001.fits'.
# 2020-03-04 17:30:52,497 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.group_scale:Step group_scale running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:52,499 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.Detector1Pipeline.group_scale:Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:30:52,510 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES=1 is a power of 2; correction not needed
# INFO:stpipe.Detector1Pipeline.group_scale:NFRAMES=1 is a power of 2; correction not needed
# 2020-03-04 17:30:52,511 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# INFO:stpipe.Detector1Pipeline.group_scale:Step will be skipped
# 2020-03-04 17:30:52,513 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# INFO:stpipe.Detector1Pipeline.group_scale:Step group_scale done
# 2020-03-04 17:30:52,605 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.dq_init:Step dq_init running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:52,607 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.Detector1Pipeline.dq_init:Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:30:52,623 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_mask_0036.fits
# INFO:stpipe.Detector1Pipeline.dq_init:Using MASK reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_mask_0036.fits
# WARNING:jwst.datamodels.dynamicdq:Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:52,772 - stpipe.Detector1Pipeline.dq_init - WARNING - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.dq_init:Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:52,870 - stpipe.Detector1Pipeline.dq_init - WARNING - Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.dq_init:Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:52,973 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# INFO:stpipe.Detector1Pipeline.dq_init:Step dq_init done
# 2020-03-04 17:30:53,069 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.saturation:Step saturation running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:53,071 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.Detector1Pipeline.saturation:Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:30:53,087 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0058.fits
# INFO:stpipe.Detector1Pipeline.saturation:Using SATURATION reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0058.fits
# WARNING:jwst.datamodels.dynamicdq:Keyword NO_SATURATION does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:53,184 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword NO_SATURATION does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.saturation:Keyword NO_SATURATION does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword FEW_SAMPLES does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:53,186 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword FEW_SAMPLES does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.saturation:Keyword FEW_SAMPLES does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword AD_SATURATION does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:53,187 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword AD_SATURATION does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.saturation:Keyword AD_SATURATION does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword WEIRD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:53,189 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword WEIRD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.saturation:Keyword WEIRD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword DEAD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:53,191 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword DEAD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.saturation:Keyword DEAD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:53,412 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# INFO:stpipe.Detector1Pipeline.saturation:Step saturation done
# 2020-03-04 17:30:53,509 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.ipc:Step ipc running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:53,511 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.Detector1Pipeline.ipc:Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:30:53,527 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0029.fits
# INFO:stpipe.Detector1Pipeline.ipc:Using IPC reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0029.fits
# 2020-03-04 17:30:53,901 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# INFO:stpipe.Detector1Pipeline.ipc:Step ipc done
# 2020-03-04 17:30:54,000 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.superbias:Step superbias running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:54,002 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.Detector1Pipeline.superbias:Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:30:54,018 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0020.fits
# INFO:stpipe.Detector1Pipeline.superbias:Using SUPERBIAS reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0020.fits
# WARNING:jwst.datamodels.dynamicdq:Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:54,180 - stpipe.Detector1Pipeline.superbias - WARNING - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.superbias:Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:54,301 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# INFO:stpipe.Detector1Pipeline.superbias:Step superbias done
# 2020-03-04 17:30:54,397 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.refpix:Step refpix running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:54,399 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# INFO:stpipe.Detector1Pipeline.refpix:Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2020-03-04 17:30:54,410 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# INFO:stpipe.Detector1Pipeline.refpix:use_side_ref_pixels = True
# 2020-03-04 17:30:54,412 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# INFO:stpipe.Detector1Pipeline.refpix:odd_even_columns = True
# 2020-03-04 17:30:54,413 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# INFO:stpipe.Detector1Pipeline.refpix:side_smoothing_length = 11
# 2020-03-04 17:30:54,414 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# INFO:stpipe.Detector1Pipeline.refpix:side_gain = 1.000000
# 2020-03-04 17:30:54,415 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# INFO:stpipe.Detector1Pipeline.refpix:odd_even_rows = True
# 2020-03-04 17:30:55,716 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# INFO:stpipe.Detector1Pipeline.refpix:Step refpix done
# 2020-03-04 17:30:55,813 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.linearity:Step linearity running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:55,816 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.Detector1Pipeline.linearity:Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:30:55,834 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0057.fits
# INFO:stpipe.Detector1Pipeline.linearity:Using Linearity reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0057.fits
# WARNING:jwst.datamodels.dynamicdq:Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:55,981 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.linearity:Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:55,983 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.linearity:Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:55,985 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.linearity:Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:55,986 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.linearity:Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:55,988 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.linearity:Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:55,990 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.linearity:Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:55,991 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.linearity:Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:56,498 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# INFO:stpipe.Detector1Pipeline.linearity:Step linearity done
# 2020-03-04 17:30:56,597 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.persistence:Step persistence running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:56,599 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# INFO:stpipe.Detector1Pipeline.persistence:Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# WARNING:jwst.datamodels.dynamicdq:Keyword WEIRD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:56,798 - stpipe.Detector1Pipeline.persistence - WARNING - Keyword WEIRD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.persistence:Keyword WEIRD_PIXEL does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:30:59,345 - stpipe.Detector1Pipeline.persistence - INFO - Saved model in jw42424001001_01101_00001_nrcb1_trapsfilled.fits
# INFO:stpipe.Detector1Pipeline.persistence:Saved model in jw42424001001_01101_00001_nrcb1_trapsfilled.fits
# 2020-03-04 17:30:59,356 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence done
# INFO:stpipe.Detector1Pipeline.persistence:Step persistence done
# 2020-03-04 17:30:59,457 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.dark_current:Step dark_current running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:30:59,460 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}
# INFO:stpipe.Detector1Pipeline.dark_current:Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}
# 2020-03-04 17:30:59,478 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_dark_0044.fits
# INFO:stpipe.Detector1Pipeline.dark_current:Using DARK reference file /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_dark_0044.fits
# WARNING:jwst.datamodels.dynamicdq:Keyword HIGH_NOISE does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:31:00,770 - stpipe.Detector1Pipeline.dark_current - WARNING - Keyword HIGH_NOISE does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.dark_current:Keyword HIGH_NOISE does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:jwst.datamodels.dynamicdq:Keyword UNSTABLE_NOISE does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:31:00,773 - stpipe.Detector1Pipeline.dark_current - WARNING - Keyword UNSTABLE_NOISE does not correspond to an existing DQ mnemonic, so will be ignored
# WARNING:stpipe.Detector1Pipeline.dark_current:Keyword UNSTABLE_NOISE does not correspond to an existing DQ mnemonic, so will be ignored
# 2020-03-04 17:31:01,358 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# INFO:stpipe.Detector1Pipeline.dark_current:Step dark_current done
# 2020-03-04 17:31:01,466 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.jump:Step jump running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:31:01,469 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'rejection_threshold': 4.0, 'maximum_cores': None, 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 200.0, 'min_jump_to_flag_neighbors': 10.0}
# INFO:stpipe.Detector1Pipeline.jump:Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'rejection_threshold': 4.0, 'maximum_cores': None, 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 200.0, 'min_jump_to_flag_neighbors': 10.0}
# 2020-03-04 17:31:01,481 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# INFO:stpipe.Detector1Pipeline.jump:CR rejection threshold = 4 sigma
# 2020-03-04 17:31:01,488 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_gain_0053.fits
# INFO:stpipe.Detector1Pipeline.jump:Using GAIN reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_gain_0053.fits
# 2020-03-04 17:31:01,528 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0039.fits
# INFO:stpipe.Detector1Pipeline.jump:Using READNOISE reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0039.fits
# 2020-03-04 17:31:07,014 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 5.533099
# INFO:stpipe.Detector1Pipeline.jump:The execution time in seconds: 5.533099
# 2020-03-04 17:31:07,019 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# INFO:stpipe.Detector1Pipeline.jump:Step jump done
# 2020-03-04 17:31:07,126 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.ramp_fit:Step ramp_fit running with args (<RampModel(1, 4, 2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:31:07,129 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'int_name': '', 'save_opt': False, 'opt_name': ''}
# INFO:stpipe.Detector1Pipeline.ramp_fit:Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'int_name': '', 'save_opt': False, 'opt_name': ''}
# 2020-03-04 17:35:54,943 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# INFO:stpipe.Detector1Pipeline.ramp_fit:Step ramp_fit done
# 2020-03-04 17:35:55,036 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.Detector1Pipeline.gain_scale:Step gain_scale running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:35:55,038 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.Detector1Pipeline.gain_scale:Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:35:55,084 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# INFO:stpipe.Detector1Pipeline.gain_scale:GAINFACT not found in gain reference file
# 2020-03-04 17:35:55,085 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# INFO:stpipe.Detector1Pipeline.gain_scale:Step will be skipped
# 2020-03-04 17:35:55,089 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# INFO:stpipe.Detector1Pipeline.gain_scale:Step gain_scale done
# 2020-03-04 17:35:55,091 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# INFO:stpipe.Detector1Pipeline:Step Detector1Pipeline done

# %% [markdown]
# This will run all of the following steps as part of this pipeline:
#
# <table class="relative-table wrapped confluenceTable"><colgroup><col style="width: 8.06452%;" /><col style="width: 72.7704%;" /><col style="width: 19.1651%;" /></colgroup><tbody><tr><td class="confluenceTd"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/group_scale/index.html#group-scale-step">Group Scale</a></p></td><td class="confluenceTd"><span style="color: #404040;">The<span>&nbsp;</span></span><code class="xref py py-obj docutils literal notranslate"><span class="pre">group_scale</span></code><span style="color: #404040;"><span>&nbsp;</span>step rescales pixel values in raw JWST science data products to correct for instances where on-board frame averaging did not result in the proper downlinked values.</span></td></tr><tr><td class="confluenceTd"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/dq_init/index.html#dq-init-step">Data Quality (DQ) Initialization</a></p></td><td class="confluenceTd"><p><span style="color: #404040;">The Data Quality (DQ) initialization step in the calibration pipeline populates the DQ mask for the input dataset.&nbsp;</span></p></td></tr><tr><td class="confluenceTd"><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/saturation/index.html#saturation-step">Saturation Flagging</a></td><td class="confluenceTd"><span style="color: #404040;">The<span>&nbsp;</span></span><code class="docutils literal notranslate"><span class="pre">saturation</span></code><span style="color: #404040;"><span>&nbsp;</span>step flags saturated pixel values.</span></td></tr><tr><td class="confluenceTd"><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/ipc/index.html#ipc-correction">Interpixel Capacitance</a></td><td class="confluenceTd"><span style="color: #404040;">The<span>&nbsp;</span></span><code class="docutils literal notranslate"><span class="pre">ipc</span></code><span style="color: #404040;"><span>&nbsp;</span>step corrects a JWST exposure for interpixel capacitance by convolving with an IPC reference image.&nbsp; This step is currently skipped in the JWST pipeline</span></td></tr><tr><td class="confluenceTd" colspan="1"><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/superbias/index.html#superbias-subtraction">Superbias Subtraction</a> &nbsp;</td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The superbias subtraction step removes the fixed detector bias from a science data set by subtracting a superbias reference image.</span></td></tr><tr><td class="confluenceTd" colspan="1"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/refpix/index.html#refpix-step">Reference Pixel Correction</a></p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The<span>&nbsp;</span></span><code class="docutils literal notranslate"><span class="pre">refpix</span></code><span style="color: #404040;"><span>&nbsp;</span>step corrects for drifts by using reference pixels.</span></td></tr><tr><td class="confluenceTd" colspan="1"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/linearity/index.html#linearity-step">Linearity Correction</a></p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The linearity step applies the &ldquo;classic&rdquo; linearity correction adapted from the HST WFC3/IR linearity correction routine, correcting science data values for detector non-linearity.</span></td></tr><tr><td class="confluenceTd" colspan="1"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/persistence/index.html#persistence-step">Persistence Correction</a></p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">Based on a model, this step computes the number of traps that are expected to have captured or released a charge during an exposure. The released charge is proportional to the persistence signal, and this will be subtracted (group by group) from the science data.</span></td></tr><tr><td class="confluenceTd" colspan="1"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/dark_current/index.html#dark-current-step">Dark Current Subtraction</a></p></td><td class="confluenceTd" colspan="1"><p>The dark current step removes dark current from a JWST exposure by subtracting dark current data stored in a dark reference file.</p></td></tr><tr><td class="confluenceTd" colspan="1"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/jump/description.html">Jump Detection</a></p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">This routine detects jumps in an exposure by looking for outliers in the up-the-ramp signal for each pixel in each integration within an input exposure.</span></td></tr><tr><td class="confluenceTd" colspan="1"><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/ramp_fitting/index.html#ramp-fitting-step">Ramp Fitting</a></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">This step determines the mean count rate, in units of counts per second, for each pixel by performing a linear fit to the data in the input file. T</span></td></tr><tr><td class="confluenceTd" colspan="1"><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/gain_scale/index.html#gain-scale-step">Gain Scale Correction</a></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The<span>&nbsp;</span></span><code class="docutils literal notranslate"><span class="pre">gain_scale</span></code><span style="color: #404040;"><span>&nbsp;</span>step rescales pixel values in JWST countrate science data products in order to correct for the effect of using a non-standard detector gain setting.<span>&nbsp;</span></span></td></tr></tbody></table>

# %% [markdown]
# # Steps

# %% [markdown]
# Individual steps can also be run instead of the Pipeline as a whole.  To produce the calibrate observation from the rate  image, the `Image2Pipeline` could be run or each of the individual steps could be run on its own:

# %%
from jwst.background import background_step 
from jwst.assign_wcs import assign_wcs_step
from jwst.flatfield import flat_field_step
from jwst.photom import photom_step

# %%
level2 = assign_wcs_step.AssignWcsStep.call(result)
level2 = flat_field_step.FlatFieldStep.call(level2)
level2 = photom_step.PhotomStep.call(level2)
# Out:
# 2020-03-04 17:35:55,205 - CRDS - ERROR -  Error determining best reference for 'pars-assignwcsstep'  =   Unknown reference type 'pars-assignwcsstep'
# 2020-03-04 17:35:55,207 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.
# INFO:stpipe.AssignWcsStep:AssignWcsStep instance created.
# 2020-03-04 17:35:55,298 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.AssignWcsStep:Step AssignWcsStep running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:35:55,300 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# INFO:stpipe.AssignWcsStep:Step AssignWcsStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2020-03-04 17:35:55,467 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep done
# INFO:stpipe.AssignWcsStep:Step AssignWcsStep done
# 2020-03-04 17:35:55,476 - CRDS - ERROR -  Error determining best reference for 'pars-flatfieldstep'  =   Unknown reference type 'pars-flatfieldstep'
# 2020-03-04 17:35:55,477 - stpipe.FlatFieldStep - INFO - FlatFieldStep instance created.
# INFO:stpipe.FlatFieldStep:FlatFieldStep instance created.
# 2020-03-04 17:35:55,571 - stpipe.FlatFieldStep - INFO - Step FlatFieldStep running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.FlatFieldStep:Step FlatFieldStep running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:35:55,573 - stpipe.FlatFieldStep - INFO - Step FlatFieldStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False}
# INFO:stpipe.FlatFieldStep:Step FlatFieldStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False}
# 2020-03-04 17:35:55,869 - stpipe.FlatFieldStep - INFO - Step FlatFieldStep done
# INFO:stpipe.FlatFieldStep:Step FlatFieldStep done
# 2020-03-04 17:35:55,878 - CRDS - ERROR -  Error determining best reference for 'pars-photomstep'  =   Unknown reference type 'pars-photomstep'
# 2020-03-04 17:35:55,879 - stpipe.PhotomStep - INFO - PhotomStep instance created.
# INFO:stpipe.PhotomStep:PhotomStep instance created.
# 2020-03-04 17:35:55,975 - stpipe.PhotomStep - INFO - Step PhotomStep running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# INFO:stpipe.PhotomStep:Step PhotomStep running with args (<ImageModel(2048, 2048) from jw42424001001_01101_00001_nrcb1_uncal.fits>,).
# 2020-03-04 17:35:55,977 - stpipe.PhotomStep - INFO - Step PhotomStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# INFO:stpipe.PhotomStep:Step PhotomStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2020-03-04 17:35:55,992 - stpipe.PhotomStep - INFO - Using photom reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_photom_0066.fits
# INFO:stpipe.PhotomStep:Using photom reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_photom_0066.fits
# 2020-03-04 17:35:55,999 - stpipe.PhotomStep - INFO - Using area reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_area_0021.fits
# INFO:stpipe.PhotomStep:Using area reference file: /home/jovyan/crds_cache/references/jwst/nircam/jwst_nircam_area_0021.fits
# 2020-03-04 17:35:56,157 - stpipe.PhotomStep - INFO - Step PhotomStep done
# INFO:stpipe.PhotomStep:Step PhotomStep done

# %% [markdown]
# The steps for the Stage 2 processing in JWST include the following steps:

# %% [markdown]
# <table class="relative-table wrapped confluenceTable"><colgroup><col style="width: 8.06452%;" /><col style="width: 72.7704%;" /><col style="width: 19.1651%;" /></colgroup><tbody><tr><td class="confluenceTd" colspan="1"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/background/index.html#background-step">Background Image Subtraction</a></p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The background subtraction step performs image-from-image subtraction in order to accomplish subtraction of background signal.</span></td><td class="confluenceTd" colspan="1">None</td></tr><tr><td class="confluenceTd" colspan="1"><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/assign_wcs/index.html#assign-wcs-step">Assign WCS</a></td><td class="confluenceTd" colspan="1">The assign WCS step&nbsp;<span style="color: #404040;">&nbsp;associates a WCS object with each science exposure.<span>&nbsp;</span></span></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The <code>DISTORTION</code> reference file contains a combination of astropy models, representing the transform from detector to the telescope V2, V3 system</span></td></tr><tr><td class="confluenceTd" colspan="1"><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/flatfield/index.html#flatfield-step">Flat-field</a></td><td class="confluenceTd" colspan="1">F<span style="color: #404040;">lat-fields an input science data set by dividing by a flat-field reference image</span></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The <code>FLAT</code> reference file contains pixel-by-pixel detector response values. It is used for all instrument modes except the NIRSpec spectroscopic modes.</span></td></tr><tr><td class="confluenceTd" colspan="1"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/photom/index.html#photom-step">Photometric Calibration</a></p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The<span>&nbsp;</span></span><code class="docutils literal notranslate"><span class="pre">photom</span></code><span style="color: #404040;"><span>&nbsp;</span>step applies flux (photometric) calibrations to a data product to convert the data from units of countrate to surface brightness (or, in some cases described below, to units of flux density).</span></td><td class="confluenceTd" colspan="1"><p>The <code>PHOTOM</code> reference file contains conversion factors for putting pixel values into physical units.</p></td></tr></tbody></table>

# %%
from matplotlib import pyplot as plt
from astropy.visualization import (MinMaxInterval, SqrtStretch, ImageNormalize)

image = level2.data
print(image.shape)
norm = ImageNormalize(image, vmin=-10, vmax=10,
                      stretch=SqrtStretch())

plt.imshow(image, norm=norm)
# Out:
# (2048, 2048)
# WARNING:py.warnings:/opt/conda/envs/wfirst-sit/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#
# 2020-03-04 20:08:50,992 - stpipe - WARNING - /opt/conda/envs/wfirst-sit/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#
# WARNING:stpipe:/opt/conda/envs/wfirst-sit/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
level2.write('jw42424001001_01101_00003_nrcb1_cal.fits')

# %%
print(level2.info())
# Out:
# filename: jw42424001001_01101_00003_nrcb1_cal.fits
# date: 2020-03-04T17:35:56.331
# model_type: ImageModel
# ----------------------------------------------------------------------
# attribute                               size                type
# ----------------------------------------------------------------------
# data                                    (2048,2048)         float32
# dq                                      (2048,2048)         uint32
# var_poisson                             (2048,2048)         float32
# var_rnoise                              (2048,2048)         float32
# err                                     (2048,2048)         float32
# var_flat                                (2048,2048)         float32
# area                                    (2048,2048)         float32

# %% [markdown]
# The processing to produce Level 3 files includes:

# %% [markdown]
# <table class="relative-table wrapped confluenceTable"><colgroup><col style="width: 96.0px;" /><col style="width: 757.0px;" /><col style="width: 201.0px;" /></colgroup><tbody><tr><th class="confluenceTh">Step</th><th class="confluenceTh">Description</th><th class="confluenceTh" colspan="1">Reference Files</th></tr><tr><td class="confluenceTd" colspan="1"><p>TweakReg</p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">This step creates image catalogs of point-like sources whose centroids are then used to compute corrections to the WCS of the input images such that sky catalogs obtained from the image catalogs using the corrected WCS will align on the sky.</span></td><td class="confluenceTd" colspan="1">Parameter Reference files</td></tr><tr><td class="confluenceTd" colspan="1"><p>SkyMatch</p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">The<span>&nbsp;</span></span><code class="docutils literal notranslate"><span class="pre">skymatch</span></code><span style="color: #404040;"><span>&nbsp;</span>step can be used to compute sky values in a collection of input images that contain both sky and source signal.<span>&nbsp;</span></span></td><td class="confluenceTd" colspan="1">None</td></tr><tr><td class="confluenceTd" colspan="1"><p>Outlier Detection</p></td><td class="confluenceTd" colspan="1"><span style="color: #404040;">Processing multiple datasets together allows for the identification of bad pixels or cosmic-rays that remain in each of the input images, many times at levels which were not detectable by the<span>&nbsp;</span></span><a class="reference internal" style="text-decoration: none;" href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/jump/index.html#jump-step"><span class="std std-ref">jump</span></a><span style="color: #404040;"><span>&nbsp;</span>step.<span>&nbsp;</span></span></td><td class="confluenceTd" colspan="1">None</td></tr><tr><td class="confluenceTd"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/resample/index.html#resample-step">Resampling</a></p></td><td class="confluenceTd"><span style="color: #404040;">This routine will resample each input 2D image based on the WCS and distortion information, and will combine multiple resampled images into a single undistorted product. </span></td><td class="confluenceTd" colspan="1">None</td></tr></tbody></table>

# %% [markdown]
# The processing to procude Level 4 files includes:

# %% [markdown]
# <table class="relative-table wrapped confluenceTable"><colgroup><col style="width: 8.06452%;" /><col style="width: 72.7704%;" /><col style="width: 19.1651%;" /></colgroup><tbody><tr><td class="confluenceTd"><p><a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/source_catalog/index.html#source-catalog-step">Source Catalog</a></p></td><td class="confluenceTd"><p>This step creates a catalog of source photometry and morphologies using <a href="https://photutils.readthedocs.io/en/stable/">photutils</a>.</p></td><td class="confluenceTd">None</td></tr></tbody></table>

# %% [markdown]
# # Developing New Features

# %% [markdown]
# An example of a commonly requested new feature is the ability to inject artificial sources into the image.  This is a toy exampe of how that might be done.

# %%
import astropy

# %%
astropy.__version__
# Out:
# '4.0'

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (16, 6)  # make the default figure size larger
matplotlib.rcParams['image.interpolation'] = 'nearest'  # don't blur/smooth image plots
from matplotlib import pyplot as plt
import webbpsf
import webbpsf.wfirst

# %% [markdown]
# Simulate a source to inject into the WFIRST detector image

# %%
wfi = webbpsf.wfirst.WFI()
xpos = 400
ypos = 400 
wfi.detector_position = (xpos, ypos)

# %%
mono_psf = wfi.calc_psf(monochromatic=1.2e-6, display=True)

# %%
#level2 = datamodels.open('jw42424001001_01101_00001_nrcb1_cal.fits')

# %%
mono_psf[0].data.shape
# Out:
# (180, 180)

# %%
mono_psf[0].data.max()
# Out:
# 0.03381649868199891

# %% [markdown]
# Make a copy of the image.   Scale the injection source and inject it into the image

# %%
sim = level2.copy()

# %%
factor = 10000
sim.data[400:580,400:580] += factor*mono_psf[0].data

# %% [markdown]
# Compare the input image and the image with the default image

# %%
from matplotlib import pyplot as plt
from astropy.visualization import (MinMaxInterval, SqrtStretch, ImageNormalize)

image = level2.data
print(image.shape)
norm = ImageNormalize(image, vmin=-10, vmax=10,
                      stretch=SqrtStretch())

plt.imshow(image, norm=norm)
# Out:
# (2048, 2048)
# WARNING:py.warnings:/opt/conda/envs/wfirst-sit/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#
# 2020-03-04 20:12:54,904 - stpipe - WARNING - /opt/conda/envs/wfirst-sit/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#
# WARNING:stpipe:/opt/conda/envs/wfirst-sit/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
image = sim.data
print(image.shape)
norm = ImageNormalize(image, vmin=-10, vmax=10,
                      stretch=SqrtStretch())

plt.imshow(image, norm=norm)
# Out:
# (2048, 2048)

# %% [markdown]
# Run a detection algorithm and see if an injected source is detected.

# %%
from astropy.stats import sigma_clipped_stats
from photutils import DAOStarFinder

# %%
mean, median, std = sigma_clipped_stats(level2.data, sigma=3.0)

# %%
daofind = DAOStarFinder(fwhm=3.0, threshold=100.*std)

# %%
level2_sources = daofind(level2.data - median)

# %%
sim_sources = daofind(sim.data - median)

# %%
print(len(sim_sources), len(level2_sources))
# Out:
# 46 45
